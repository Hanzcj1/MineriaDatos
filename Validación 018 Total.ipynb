# %%
import pandas as pd

df_18 = pd.read_csv('../MIGTABO18X.txt',sep="|")
df_columns_18 = pd.read_csv('Campos MIGTAB018X.csv',sep=";")
df_18.columns = df_columns_18['NombreColumna'].tolist()

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.expand_frame_repr', False)

# %%
# Cargar el archivo CSV
df = df_18

# Asegurar los tipos necesarios para las validaciones
df["op_moneda"] = pd.to_numeric(df["op_moneda"], errors="coerce")
df["op_monto"] = pd.to_numeric(df["op_monto"], errors="coerce")
df["op_monto_aprobado"] = pd.to_numeric(df["op_monto_aprobado"], errors="coerce")

errores = []

# 1. op_operacion: NO NULL
val = df["op_operacion"].isnull()
errores.append(df[val][["op_operacion"]].assign(campo_error="op_operacion"))

# 2. op_banco: puede ser NULL
# No se valida

# 3. op_anterior: puede ser NULL
# No se valida

# 4. op_migrada: puede ser NULL
# No se valida

# 5. op_cliente: NO NULL
val = df["op_cliente"].isnull()
errores.append(df[val][["op_operacion"]].assign(campo_error="op_cliente"))

# 6. op_nombre: NO puede tener números ni caracteres especiales
val = df["op_nombre"].str.contains(r"[^a-zA-ZñÑáéíóúÁÉÍÓÚ\s\.,]", na=False)
errores.append(df[val][["op_operacion"]].assign(campo_error="op_nombre"))

# 7. op_sector: NO NULL
val = df["op_sector"].isnull()
errores.append(df[val][["op_operacion"]].assign(campo_error="op_sector"))

# 8. op_toperacion: NO NULL
val = df["op_toperacion"].isnull()
errores.append(df[val][["op_operacion"]].assign(campo_error="op_toperacion"))

# 9. op_oficina: NO NULL
val = df["op_oficina"].isnull()
errores.append(df[val][["op_operacion"]].assign(campo_error="op_oficina"))

# 10. op_moneda: DEBE SER CERO
val = df["op_moneda"] != 0
errores.append(df[val][["op_operacion"]].assign(campo_error="op_moneda"))

# 11. op_comentario: no obligatorio, solo validación si inicia con "REGISTRO MIGRADO el"
# No se valida si no es obligatorio

# 12. op_oficial: NO NULL
val = df["op_oficial"].isnull()
errores.append(df[val][["op_operacion"]].assign(campo_error="op_oficial"))

# 13. op_fecha_ini: NO NULL
val = df["op_fecha_ini"].isnull()
errores.append(df[val][["op_operacion"]].assign(campo_error="op_fecha_ini"))

# 14. op_fecha_fin: NO NULL
val = df["op_fecha_fin"].isnull()
errores.append(df[val][["op_operacion"]].assign(campo_error="op_fecha_fin"))

# 15. op_fecha_ult_proceso: NO NULL
val = df["op_fecha_ult_proceso"].isnull()
errores.append(df[val][["op_operacion"]].assign(campo_error="op_fecha_ult_proceso"))

# 16. op_fecha_liq: NO NULL
val = df["op_fecha_liq"].isnull()
errores.append(df[val][["op_operacion"]].assign(campo_error="op_fecha_liq"))

# 17. op_fecha_reajuste: puede ser NULL
# No se valida

# 18. op_monto: NO NULL y MAYOR A CERO
val = df["op_monto"].isnull() | (df["op_monto"] <= 0)
errores.append(df[val][["op_operacion"]].assign(campo_error="op_monto"))

# 19. op_monto_aprobado: NO NULL y MAYOR A CERO
val = df["op_monto_aprobado"].isnull() | (df["op_monto_aprobado"] <= 0)
errores.append(df[val][["op_operacion"]].assign(campo_error="op_monto_aprobado"))

# 20. op_destino: NO NULL
val = df["op_destino"].isnull()
errores.append(df[val][["op_operacion"]].assign(campo_error="op_destino"))

# %%
# Validaciones de la 21 a la 40

# 21. op_lin_credito: DEBE SER NULL
val = df["op_lin_credito"].notnull()
errores.append(df[val][["op_operacion"]].assign(campo_error="op_lin_credito"))

# 22. op_ciudad: NO NULL
val = df["op_ciudad"].isnull()
errores.append(df[val][["op_operacion"]].assign(campo_error="op_ciudad"))

# 23. op_estado: NO NULL
val = df["op_estado"].isnull()
errores.append(df[val][["op_operacion"]].assign(campo_error="op_estado"))

# 24. op_periodo_reajuste: DEBE SER CERO
val = df["op_periodo_reajuste"] != "0"
errores.append(df[val][["op_operacion"]].assign(campo_error="op_periodo_reajuste"))

# 25. op_reajuste_especial: DEBE SER "S" o "N", o NULL si no aplica
val = ~df["op_reajuste_especial"].isin(["S", "N", None, ""])
errores.append(df[val][["op_operacion"]].assign(campo_error="op_reajuste_especial"))

# 26. op_tipo: DEBE SER "N"
val = df["op_tipo"] != "N"
errores.append(df[val][["op_operacion"]].assign(campo_error="op_tipo"))

# 27. op_forma_pago: DEBE SER "C"
val = df["op_forma_pago"] != "C"
errores.append(df[val][["op_operacion"]].assign(campo_error="op_forma_pago"))

# 28. op_dias_anio: DEBE SER "360"
val = df["op_dias_anio"] != "360"
errores.append(df[val][["op_operacion"]].assign(campo_error="op_dias_anio"))

# 29. op_tipo_amortizacion: NO NULL
val = df["op_tipo_amortizacion"].isnull()
errores.append(df[val][["op_operacion"]].assign(campo_error="op_tipo_amortizacion"))

# 30. op_cuota_completa: DEBE SER "N"
val = df["op_cuota_completa"] != "N"
errores.append(df[val][["op_operacion"]].assign(campo_error="op_cuota_completa"))

# 31. op_tipo_cobro: DEBE SER "A"
val = df["op_tipo_cobro"] != "A"
errores.append(df[val][["op_operacion"]].assign(campo_error="op_tipo_cobro"))

# 32. op_tipo_reduccion: DEBE SER "T"
val = df["op_tipo_reduccion"] != "T"
errores.append(df[val][["op_operacion"]].assign(campo_error="op_tipo_reduccion"))

# 33. op_aceptar_anticipos: DEBE SER "S"
val = df["op_aceptar_anticipos"] != "S"
errores.append(df[val][["op_operacion"]].assign(campo_error="op_aceptar_anticipos"))

# 34. op_precancelacion: DEBE SER "S"
val = df["op_precancelacion"] != "S"
errores.append(df[val][["op_operacion"]].assign(campo_error="op_precancelacion"))

# 35. op_tipo_aplicacion: DEBE SER "D"
val = df["op_tipo_aplicacion"] != "D"
errores.append(df[val][["op_operacion"]].assign(campo_error="op_tipo_aplicacion"))

# 36. op_tplazo: DEBE SER "M"
val = df["op_tplazo"] != "M"
errores.append(df[val][["op_operacion"]].assign(campo_error="op_tplazo"))

# 37. op_plazo: NO NULL
val = df["op_plazo"].isnull()
errores.append(df[val][["op_operacion"]].assign(campo_error="op_plazo"))

# 38. op_tdividendo: DEBE SER "M"
val = df["op_tdividendo"] != "M"
errores.append(df[val][["op_operacion"]].assign(campo_error="op_tdividendo"))

# 39. op_periodo_cap: DEBE SER 1 si está presente
val = df["op_periodo_cap"].notnull() & (df["op_periodo_cap"] != "1")
errores.append(df[val][["op_operacion"]].assign(campo_error="op_periodo_cap"))

# 40. op_periodo_int: DEBE SER 1 si está presente
val = df["op_periodo_int"].notnull() & (df["op_periodo_int"] != "1")
errores.append(df[val][["op_operacion"]].assign(campo_error="op_periodo_int"))

# %%
# 41. op_dist_gracia: "S", "N" o NULL
val = ~df["op_dist_gracia"].isin(["S", "N", None, ""])
errores.append(df[val][["op_operacion"]].assign(campo_error="op_dist_gracia"))

# 42. op_gracia_cap: Si aplica, debe ser >= 0, de lo contrario 0
val = df["op_gracia_cap"].notnull() & (df["op_gracia_cap"] < 0)
errores.append(df[val][["op_operacion"]].assign(campo_error="op_gracia_cap"))

# 43. op_gracia_int: Igual a la regla anterior
val = df["op_gracia_int"].notnull() & (df["op_gracia_int"] < 0)
errores.append(df[val][["op_operacion"]].assign(campo_error="op_gracia_int"))

# 44. op_dia_fijo: NO PUEDE SER NULL, debe ser entre 1 y 31 o 0 si no aplica
val = df["op_dia_fijo"].isnull() | ~df["op_dia_fijo"].isin(range(0, 32))
errores.append(df[val][["op_operacion"]].assign(campo_error="op_dia_fijo"))

# 45. op_cuota: depende del tipo de amortización (requiere validación cruzada)
# Si tipo = FRANCES -> cuota > 0
val = df["op_tipo_amortizacion"] == "FRANCES"
val2 = df[val]["op_cuota"] <= 0
errores.append(df[val][val2][["op_operacion"]].assign(campo_error="op_cuota_FRANCES"))

# Si tipo = MANUAL -> cuota debe ser 0
val = df["op_tipo_amortizacion"] == "MANUAL"
val2 = df[val]["op_cuota"] != 0
errores.append(df[val][val2][["op_operacion"]].assign(campo_error="op_cuota_MANUAL"))

# Si tipo = ALEMANIA -> cuota > 0
val = df["op_tipo_amortizacion"] == "ALEMANIA"
val2 = df[val]["op_cuota"] <= 0
errores.append(df[val][val2][["op_operacion"]].assign(campo_error="op_cuota_ALEMANIA"))

# 46. op_evitar_feriados: debe ser “S”
val = df["op_evitar_feriados"] != "S"
errores.append(df[val][["op_operacion"]].assign(campo_error="op_evitar_feriados"))

# 47. op_num_renovacion: >= 0 si aplica, NULL si no ha habido renovaciones
val = df["op_num_renovacion"].notnull() & (df["op_num_renovacion"] < 0)
errores.append(df[val][["op_operacion"]].assign(campo_error="op_num_renovacion"))

# 48. op_renovacion: debe ser “S” o “N”
val = ~df["op_renovacion"].isin(["S", "N"])
errores.append(df[val][["op_operacion"]].assign(campo_error="op_renovacion"))

# 49. op_mes_gracia: DEBE SER 0
val = df["op_mes_gracia"] != 0
errores.append(df[val][["op_operacion"]].assign(campo_error="op_mes_gracia"))

# 50. op_reajustable: "N" para TASA FIJA, "S" para TASA VARIABLE (requiere tasa)
#val = (df["op_tasa_tipo"] == "FIJA") & (df["op_reajustable"] != "N")
#errores.append(df[val][["op_operacion"]].assign(campo_error="op_reajustable_FIJA"))

#val = (df["op_tasa_tipo"] == "VARIABLE") & (df["op_reajustable"] != "S")
#errores.append(df[val][["op_operacion"]].assign(campo_error="op_reajustable_VARIABLE"))

# 51. op_dias_clausula: debe ser CERO
val = df["op_dias_clausula"] != 0
errores.append(df[val][["op_operacion"]].assign(campo_error="op_dias_clausula"))

# 52-54. op_divcap_original, op_clausula_aplicada, op_traslado_ingresos: deben ser NULL
for campo in ["op_divcap_original", "op_clausula_aplicada", "op_traslado_ingresos"]:
    val = df[campo].notnull()
    errores.append(df[val][["op_operacion"]].assign(campo_error=campo))

# 55-56. op_periodo_crecimiento, op_tasa_crecimiento: deben ser NULL
for campo in ["op_periodo_crecimiento", "op_tasa_crecimiento"]:
    val = df[campo].notnull()
    errores.append(df[val][["op_operacion"]].assign(campo_error=campo))

# 57-59. op_direccion, op_opcion_cap, op_tasa_cap: deben ser NULL
for campo in ["op_direccion", "op_opcion_cap", "op_tasa_cap"]:
    val = df[campo].notnull()
    errores.append(df[val][["op_operacion"]].assign(campo_error=campo))

# 60. op_dividendo_cap: debe ser NULL
val = df["op_dividendo_cap"].notnull()
errores.append(df[val][["op_operacion"]].assign(campo_error="op_dividendo_cap"))

# %%
print(df.columns.tolist())
# Out:
# ['op_operacion', 'op_banco', 'op_anterior', 'op_migrada', 'op_cliente', 'op_nombre', 'op_sector', 'op_toperacion', 'op_oficina', 'op_moneda', 'op_comentario', 'op_oficial', 'op_fecha_ini', 'op_fecha_fin', 'op_fecha_ult_proceso', 'op_fecha_liq', 'op_fecha_reajuste', 'op_monto', 'op_monto_aprobado', 'op_destino', 'op_lin_credito', 'op_ciudad', 'op_estado', 'op_periodo_reajuste', 'op_reajuste_especial', 'op_tipo', 'op_forma_pago', 'op_dias_anio', 'op_tipo_amortizacion', 'op_cuota_completa', 'op_tipo_cobro', 'op_tipo_reduccion', 'op_aceptar_anticipos', 'op_precancelacion', 'op_tipo_aplicacion', 'op_tplazo', 'op_plazo', 'op_tdividendo', 'op_periodo_cap', 'op_periodo_int', 'op_dist_gracia', 'op_gracia_cap', 'op_gracia_int', 'op_dia_fijo', 'op_cuota', 'op_evitar_feriados', 'op_num_renovacion', 'op_renovacion', 'op_mes_gracia', 'op_reajustable', 'op_dias_clausula', 'op_divcap_original', 'op_clausula_aplicada', 'op_traslado_ingresos', 'op_periodo_crecimiento', 'op_tasa_crecimiento', 'op_direccion', 'op_opcion_cap', 'op_tasa_cap', 'op_dividendo_cap', 'op_clase', 'op_origen_fondos', 'op_calificacion', 'op_estado_cobranza', 'op_numero_reest', 'op_edad', 'op_tipo_crecimiento', 'op_base_calculo', 'op_prd_cobis', 'op_ref_exterior', 'op_sujeta_nego', 'op_dia_habil', 'op_recalcular_plazo', 'op_usar_tequivalente', 'op_fondos_propios', 'op_nro_red', 'op_tipo_redondeo', 'op_sal_pro_pon', 'op_tipo_empresa', 'op_validacion', 'op_fecha_pri_cuot', 'op_gar_admisible', 'op_causacion', 'op_convierte_tasa', 'op_reestructuracion', 'op_fecha_ult_causacion', 'op_fecha_prox_segven', 'op_suspendio', 'op_fecha_suspenso', 'op_honorarios_cobranza', 'op_banca', 'op_promocion', 'op_acepta_ren', 'op_emprendimiento', 'op_valor_cat', 'op_grupo', 'op_ref_grupal', 'op_grupal', 'op_fondeador', 'op_admin_individual', 'op_estado_hijas', 'op_tipo_renovacion\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ', 'op_tipo_reest', 'op_fecha_reest\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ', 'op_fecha_reest_noestandar\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ', 'op_beneficio_feci', 'op_beneficio_tinteres', 'op_base_tasa_desc', 'op_tir', 'op_cuota_ballom', 'op_div_dist_gracia\xa0 ', 'op_beneficio_empleado', 'op_fecha_ult_pago', 'op_fecha_ult_pago_cap', 'op_fecha_ult_pago_int', 'op_monto_ult_pago', 'op_monto_ult_pago_cap', 'op_monto_ult_pago_int', 'op_compra_id_externo', 'op_compra_activa', 'op_compra_valor', 'op_compra_devengando', 'op_vta_comprador', 'op_vta_fecha', 'op_vta_fecha_recompra', 'op_fecha_corte']

# %%
# 61. op_clase: debe ser el código del tipo de crédito (revisar fuente externa)
# Supongamos que debe pertenecer a un set válido
tipos_credito_validos = {"TC01", "TC02", "TC03"}  # Ajustar según catálogo
val = ~df["op_clase"].isin(tipos_credito_validos)
errores.append(df[val][["op_operacion"]].assign(campo_error="op_clase"))

# 62. op_origen_fondos: debe ser 1
val = df["op_origen_fondos"] != "1"
errores.append(df[val][["op_operacion"]].assign(campo_error="op_origen_fondos"))

# 63-64. op_calificacion, op_estado_cobranza: deben ser NULL
for campo in ["op_calificacion", "op_estado_cobranza"]:
    val = df[campo].notnull()
    errores.append(df[val][["op_operacion"]].assign(campo_error=campo))

# 65. op_numero_reest: entero ≥ 0 o NULL si no aplica
val = df["op_numero_reest"].notnull() & (df["op_numero_reest"] < 0)
errores.append(df[val][["op_operacion"]].assign(campo_error="op_numero_reest"))

# 66. op_edad: debe ser NULL
val = df["op_edad"].notnull()
errores.append(df[val][["op_operacion"]].assign(campo_error="op_edad"))

# 67. op_tipo_crecimiento: debe ser "A"
val = df["op_tipo_crecimiento"] != "A"
errores.append(df[val][["op_operacion"]].assign(campo_error="op_tipo_crecimiento"))

# 68. op_base_calculo: debe ser "E"
val = df["op_base_calculo"] != "E"
errores.append(df[val][["op_operacion"]].assign(campo_error="op_base_calculo"))

# 69. op_prd_cobis: debe ser 7
val = df["op_prd_cobis"] != 7
errores.append(df[val][["op_operacion"]].assign(campo_error="op_prd_cobis"))

# 70. op_ref_exterior: debe ser NULL
val = df["op_ref_exterior"].notnull()
errores.append(df[val][["op_operacion"]].assign(campo_error="op_ref_exterior"))

# 71-72. op_sujeta_nego, op_dia_habil: deben ser "N"
for campo in ["op_sujeta_nego", "op_dia_habil"]:
    val = df[campo] != "N"
    errores.append(df[val][["op_operacion"]].assign(campo_error=campo))

# 73-74. op_recalcular_plazo, op_usar_tequivalente: deben ser NULL
for campo in ["op_recalcular_plazo", "op_usar_tequivalente"]:
    val = df[campo].notnull()
    errores.append(df[val][["op_operacion"]].assign(campo_error=campo))

# 75. op_fondos_propios: debe ser "S"
val = df["op_fondos_propios"] != "S"
errores.append(df[val][["op_operacion"]].assign(campo_error="op_fondos_propios"))

# 76. op_nro_red: debe ser NULL
val = df["op_nro_red"].notnull()
errores.append(df[val][["op_operacion"]].assign(campo_error="op_nro_red"))

# 77. op_tipo_redondeo: debe ser NULL
val = df["op_tipo_redondeo"].notnull()
errores.append(df[val][["op_operacion"]].assign(campo_error="op_tipo_redondeo"))

# 78. op_sal_pro_pon: debe ser NULL
val = df["op_sal_pro_pon"].notnull()
errores.append(df[val][["op_operacion"]].assign(campo_error="op_sal_pro_pon"))

# 79. op_tipo_empresa: debe tener el código CIIU (no NULL)
val = df["op_tipo_empresa"].isnull() | (df["op_tipo_empresa"] == "")
errores.append(df[val][["op_operacion"]].assign(campo_error="op_tipo_empresa"))

# 80. op_validacion: debe ser NULL
val = df["op_validacion"].notnull()
errores.append(df[val][["op_operacion"]].assign(campo_error="op_validacion"))

# %%
# 81. op_fecha_pri_cuot: Fecha de la primera cuota (YYYYMMDD), puede ser NULL si no aplica
val = ~pd.to_datetime(df["op_fecha_pri_cuot"], errors="coerce").notna()
errores.append(df[val][["op_operacion"]].assign(campo_error="op_fecha_pri_cuot"))

# 82. op_gar_admisible: debe ser "S" o "N"
val = ~df["op_gar_admisible"].isin(["S", "N"])
errores.append(df[val][["op_operacion"]].assign(campo_error="op_gar_admisible"))

# 83. op_causacion: debe ser "F", "L" o NULL
val = ~(df["op_causacion"].isin(["F", "L"]) | df["op_causacion"].isnull())
errores.append(df[val][["op_operacion"]].assign(campo_error="op_causacion"))

# 84. op_convierte_tasa: debe ser NULL
val = ~df["op_convierte_tasa"].isnull()
errores.append(df[val][["op_operacion"]].assign(campo_error="op_convierte_tasa"))

# 85. op_reestructuracion: debe ser siempre "S"
val = df["op_reestructuracion"] != "S"
errores.append(df[val][["op_operacion"]].assign(campo_error="op_reestructuracion"))

# 86. op_fecha_ult_causacion: debe ser NULL
val = ~df["op_fecha_ult_causacion"].isnull()
errores.append(df[val][["op_operacion"]].assign(campo_error="op_fecha_ult_causacion"))

# 87. op_fecha_prox_segven: debe ser NULL
val = ~df["op_fecha_prox_segven"].isnull()
errores.append(df[val][["op_operacion"]].assign(campo_error="op_fecha_prox_segven"))

# 88. op_suspendio: debe ser "S" o "N"
val = ~df["op_suspendio"].isin(["S", "N"])
errores.append(df[val][["op_operacion"]].assign(campo_error="op_suspendio"))

# 89. op_fecha_suspenso: debe ser fecha válida o NULL
val = ~(pd.to_datetime(df["op_fecha_suspenso"], errors="coerce").notna() | df["op_fecha_suspenso"].isnull())
errores.append(df[val][["op_operacion"]].assign(campo_error="op_fecha_suspenso"))

# 90. op_honorarios_cobranza: debe ser NULL
val = ~df["op_honorarios_cobranza"].isnull()
errores.append(df[val][["op_operacion"]].assign(campo_error="op_honorarios_cobranza"))

# 91. op_banca: NO NULL
val = df["op_banca"].isnull()
errores.append(df[val][["op_operacion"]].assign(campo_error="op_banca"))

# 92. op_promocion: "S", "N" o NULL
val = ~(df["op_promocion"].isin(["S", "N"]) | df["op_promocion"].isnull())
errores.append(df[val][["op_operacion"]].assign(campo_error="op_promocion"))

# 93. op_acepta_ren: "S", "N" o NULL
val = ~(df["op_acepta_ren"].isin(["S", "N"]) | df["op_acepta_ren"].isnull())
errores.append(df[val][["op_operacion"]].assign(campo_error="op_acepta_ren"))

# 94. op_emprendimiento: "S", "N" o NULL
val = ~(df["op_emprendimiento"].isin(["S", "N"]) | df["op_emprendimiento"].isnull())
errores.append(df[val][["op_operacion"]].assign(campo_error="op_emprendimiento"))

# 95. op_valor_cat: debe ser NULL
val = ~df["op_valor_cat"].isnull()
errores.append(df[val][["op_operacion"]].assign(campo_error="op_valor_cat"))

# 96. op_grupo: puede ser NULL, si existe debe ser alfanumérico
df["op_grupo"] = df["op_grupo"].astype(str)
val = ~(df["op_grupo"].str.match(r'^[A-Za-z0-9]+$') | df["op_grupo"].isin(["None", "nan"]))
errores.append(df[val][["op_operacion"]].assign(campo_error="op_grupo"))

# 97. op_ref_grupal: puede ser NULL, si existe debe ser alfanumérico
df["op_ref_grupal"] = df["op_ref_grupal"].astype(str)
val = ~(df["op_ref_grupal"].str.match(r'^[A-Za-z0-9]+$') | df["op_ref_grupal"].isin(["None", "nan"]))
errores.append(df[val][["op_operacion"]].assign(campo_error="op_ref_grupal"))

# 98. op_grupal: "S" o "N"
val = ~df["op_grupal"].isin(["S", "N"])
errores.append(df[val][["op_operacion"]].assign(campo_error="op_grupal"))

# 99. op_fondeador: NO NULL
val = df["op_fondeador"].isnull()
errores.append(df[val][["op_operacion"]].assign(campo_error="op_fondeador"))

# 100. op_admin_individual: "S" o "N"
val = ~df["op_admin_individual"].isin(["S", "N"])
errores.append(df[val][["op_operacion"]].assign(campo_error="op_admin_individual"))

# %%
# 101. op_estado_hijas: debe ser NULL
val = ~df["op_estado_hijas"].isnull()
errores.append(df[val][["op_operacion"]].assign(campo_error="op_estado_hijas"))

# 102. op_tipo_renovacion: debe ser NULL
val = ~df["op_tipo_renovacion\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 "].isnull()
errores.append(df[val][["op_operacion"]].assign(campo_error="op_tipo_renovacion"))

# 103. op_tipo_reest: debe ser NULL
val = ~df["op_tipo_reest"].isnull()
errores.append(df[val][["op_operacion"]].assign(campo_error="op_tipo_reest"))

# 104. op_fecha_reest: debe ser NULL
val = ~df["op_fecha_reest\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 "].isnull()
errores.append(df[val][["op_operacion"]].assign(campo_error="op_fecha_reest"))

# 105. op_fecha_reest_noestandar: debe ser NULL
val = ~df["op_fecha_reest_noestandar\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 "].isnull()
errores.append(df[val][["op_operacion"]].assign(campo_error="op_fecha_reest_noestandar"))

# 106. op_beneficio_feci: "S", "N" o NULL
val = ~(df["op_beneficio_feci"].isin(["S", "N"]) | df["op_beneficio_feci"].isnull())
errores.append(df[val][["op_operacion"]].assign(campo_error="op_beneficio_feci"))

# 107. op_beneficio_tinteres: "S", "N" o NULL
val = ~(df["op_beneficio_tinteres"].isin(["S", "N"]) | df["op_beneficio_tinteres"].isnull())
errores.append(df[val][["op_operacion"]].assign(campo_error="op_beneficio_tinteres"))

# 108. op_base_tasa_desc: "S", "N" o NULL
val = ~(df["op_base_tasa_desc"].isin(["S", "N"]) | df["op_base_tasa_desc"].isnull())
errores.append(df[val][["op_operacion"]].assign(campo_error="op_base_tasa_desc"))

# 110. op_cuota_ballom: debe ser NULL
val = ~df["op_cuota_ballom"].isnull()
errores.append(df[val][["op_operacion"]].assign(campo_error="op_cuota_ballom"))

# 112. op_beneficio_empleado: "S", "N" o NULL
val = ~(df["op_beneficio_empleado"].isin(["S", "N"]) | df["op_beneficio_empleado"].isnull())
errores.append(df[val][["op_operacion"]].assign(campo_error="op_beneficio_empleado"))

# 113 a 120: deben ser NULL
for col in [
    "op_fecha_ult_pago", "op_fecha_ult_pago_cap", "op_fecha_ult_pago_int",
    "op_monto_ult_pago", "op_monto_ult_pago_cap", "op_monto_ult_pago_int",
    "op_compra_id_externo", "op_compra_activa"
]:
    val = ~df[col].isnull()
    errores.append(df[val][["op_operacion"]].assign(campo_error=col))

#errores = []

for col in [
    "op_compra_valor", "op_compra_devengando", "op_vta_comprador",
    "op_vta_fecha", "op_vta_fecha_recompra", "op_fecha_corte"
]:
    val = ~df[col].isnull()
    errores.append(df[val][["op_operacion"]].assign(campo_error=col))

df_errores = pd.concat(errores, ignore_index=True)

# %%
df_errores
# Out:
#       op_operacion             campo_error
# 0           630000               op_nombre
# 1            15163               op_moneda
# 2            16353               op_moneda
# 3            25224               op_moneda
# 4            25433               op_moneda
# 5            25458               op_moneda
# 6            25499               op_moneda
# 7            25814               op_moneda
# 8            25883               op_moneda
# 9            25974               op_moneda
# 10           25992               op_moneda
# 11           26025               op_moneda
# 12           26114               op_moneda
# 13           10000               op_moneda
# 14           20000               op_moneda
# 15           30000               op_moneda
# 16           40000               op_moneda
# 17           50000               op_moneda
# 18           60000               op_moneda
# 19           70000               op_moneda
# 20           80000               op_moneda
# 21           90000               op_moneda
# 22          100000               op_moneda
# 23          110000               op_moneda
# 24          120000               op_moneda
# 25          130000               op_moneda
# 26          140000               op_moneda
# 27          150000               op_moneda
# 28          160000               op_moneda
# 29          170000               op_moneda
# 30          180000               op_moneda
# 31          190000               op_moneda
# 32          200000               op_moneda
# 33          210000               op_moneda
# 34          220000               op_moneda
# 35          230000               op_moneda
# 36          240000               op_moneda
# 37          250000               op_moneda
# 38          260000               op_moneda
# 39          270000               op_moneda
# 40          280000               op_moneda
# 41          290000               op_moneda
# 42          300000               op_moneda
# 43          310000               op_moneda
# 44          320000               op_moneda
# 45          330000               op_moneda
# 46          340000               op_moneda
# 47          350000               op_moneda
# 48          360000               op_moneda
# 49          370000               op_moneda
# 50          380000               op_moneda
# 51          390000               op_moneda
# 52          400000               op_moneda
# 53          410000               op_moneda
# 54          420000               op_moneda
# 55          430000               op_moneda
# 56          440000               op_moneda
# 57          450000               op_moneda
# 58          460000               op_moneda
# 59          470000               op_moneda
# 60          680000               op_moneda
# 61          690000               op_moneda
# 62          700000               op_moneda
# 63          710000               op_moneda
# 64          720000               op_moneda
# 65          730000               op_moneda
# 66          740000               op_moneda
# 67          750000               op_moneda
# 68          760000               op_moneda
# 69          770000               op_moneda
# 70          780000               op_moneda
# 71          790000               op_moneda
# 72          800000               op_moneda
# 73          810000               op_moneda
# 74          820000               op_moneda
# 75          830000               op_moneda
# 76          840000               op_moneda
# 77          850000               op_moneda
# 78          860000               op_moneda
# 79          870000               op_moneda
# 80          480000               op_moneda
# 81          490000               op_moneda
# 82          500000               op_moneda
# 83          510000               op_moneda
# 84          520000               op_moneda
# 85          530000               op_moneda
# 86          540000               op_moneda
# 87          550000               op_moneda
# 88          560000               op_moneda
# 89          570000               op_moneda
# 90          580000               op_moneda
# 91          590000               op_moneda
# 92          600000               op_moneda
# 93          610000               op_moneda
# 94          620000               op_moneda
# 95          630000               op_moneda
# 96          640000               op_moneda
# 97          650000               op_moneda
# 98          660000               op_moneda
# 99          670000               op_moneda
# 100          15163                op_monto
# 101          16353                op_monto
# 102          25224                op_monto
# 103          25433                op_monto
# 104          25458                op_monto
# 105          25499                op_monto
# 106          25814                op_monto
# 107          25883                op_monto
# 108          25974                op_monto
# 109          25992                op_monto
# 110          26025                op_monto
# 111          26114                op_monto
# 112          10000                op_monto
# 113          20000                op_monto
# 114          30000                op_monto
# 115          40000                op_monto
# 116          50000                op_monto
# 117          60000                op_monto
# 118          70000                op_monto
# 119          80000                op_monto
# 120          90000                op_monto
# 121         100000                op_monto
# 122         110000                op_monto
# 123         120000                op_monto
# 124         130000                op_monto
# 125         140000                op_monto
# 126         150000                op_monto
# 127         160000                op_monto
# 128         170000                op_monto
# 129         180000                op_monto
# 130         190000                op_monto
# 131         200000                op_monto
# 132         210000                op_monto
# 133         220000                op_monto
# 134         230000                op_monto
# 135         240000                op_monto
# 136         250000                op_monto
# 137         260000                op_monto
# 138         270000                op_monto
# 139         280000                op_monto
# 140         290000                op_monto
# 141         300000                op_monto
# 142         310000                op_monto
# 143         320000                op_monto
# 144         330000                op_monto
# 145         340000                op_monto
# 146         350000                op_monto
# 147         360000                op_monto
# 148         370000                op_monto
# 149         380000                op_monto
# 150         390000                op_monto
# 151         400000                op_monto
# 152         410000                op_monto
# 153         420000                op_monto
# 154         430000                op_monto
# 155         440000                op_monto
# 156         450000                op_monto
# 157         460000                op_monto
# 158         470000                op_monto
# 159         680000                op_monto
# 160         690000                op_monto
# 161         700000                op_monto
# 162         710000                op_monto
# 163         720000                op_monto
# 164         730000                op_monto
# 165         740000                op_monto
# 166         750000                op_monto
# 167         760000                op_monto
# 168         770000                op_monto
# 169         780000                op_monto
# 170         790000                op_monto
# 171         800000                op_monto
# 172         810000                op_monto
# 173         820000                op_monto
# 174         830000                op_monto
# 175         840000                op_monto
# 176         850000                op_monto
# 177         860000                op_monto
# 178         870000                op_monto
# 179         480000                op_monto
# 180         490000                op_monto
# 181         500000                op_monto
# 182         510000                op_monto
# 183         520000                op_monto
# 184         530000                op_monto
# 185         540000                op_monto
# 186         550000                op_monto
# 187         560000                op_monto
# 188         570000                op_monto
# 189         580000                op_monto
# 190         590000                op_monto
# 191         600000                op_monto
# 192         610000                op_monto
# 193         620000                op_monto
# 194         630000                op_monto
# 195         640000                op_monto
# 196         650000                op_monto
# 197         660000                op_monto
# 198         670000                op_monto
# 199          15163       op_monto_aprobado
# 200          16353       op_monto_aprobado
# 201          25224       op_monto_aprobado
# 202          25433       op_monto_aprobado
# 203          25458       op_monto_aprobado
# 204          25499       op_monto_aprobado
# 205          25814       op_monto_aprobado
# 206          25883       op_monto_aprobado
# 207          25974       op_monto_aprobado
# 208          25992       op_monto_aprobado
# 209          26025       op_monto_aprobado
# 210          26114       op_monto_aprobado
# 211          10000       op_monto_aprobado
# 212          20000       op_monto_aprobado
# 213          30000       op_monto_aprobado
# 214          40000       op_monto_aprobado
# 215          50000       op_monto_aprobado
# 216          60000       op_monto_aprobado
# 217          70000       op_monto_aprobado
# 218          80000       op_monto_aprobado
# 219          90000       op_monto_aprobado
# 220         100000       op_monto_aprobado
# 221         110000       op_monto_aprobado
# 222         120000       op_monto_aprobado
# 223         130000       op_monto_aprobado
# 224         140000       op_monto_aprobado
# 225         150000       op_monto_aprobado
# 226         160000       op_monto_aprobado
# 227         170000       op_monto_aprobado
# 228         180000       op_monto_aprobado
# 229         190000       op_monto_aprobado
# 230         200000       op_monto_aprobado
# 231         210000       op_monto_aprobado
# 232         220000       op_monto_aprobado
# 233         230000       op_monto_aprobado
# 234         240000       op_monto_aprobado
# 235         250000       op_monto_aprobado
# 236         260000       op_monto_aprobado
# 237         270000       op_monto_aprobado
# 238         280000       op_monto_aprobado
# 239         290000       op_monto_aprobado
# 240         300000       op_monto_aprobado
# 241         310000       op_monto_aprobado
# 242         320000       op_monto_aprobado
# 243         330000       op_monto_aprobado
# 244         340000       op_monto_aprobado
# 245         350000       op_monto_aprobado
# 246         360000       op_monto_aprobado
# 247         370000       op_monto_aprobado
# 248         380000       op_monto_aprobado
# 249         390000       op_monto_aprobado
# 250         400000       op_monto_aprobado
# 251         410000       op_monto_aprobado
# 252         420000       op_monto_aprobado
# 253         430000       op_monto_aprobado
# 254         440000       op_monto_aprobado
# 255         450000       op_monto_aprobado
# 256         460000       op_monto_aprobado
# 257         470000       op_monto_aprobado
# 258         680000       op_monto_aprobado
# 259         690000       op_monto_aprobado
# 260         700000       op_monto_aprobado
# 261         710000       op_monto_aprobado
# 262         720000       op_monto_aprobado
# 263         730000       op_monto_aprobado
# 264         740000       op_monto_aprobado
# 265         750000       op_monto_aprobado
# 266         760000       op_monto_aprobado
# 267         770000       op_monto_aprobado
# 268         780000       op_monto_aprobado
# 269         790000       op_monto_aprobado
# 270         800000       op_monto_aprobado
# 271         810000       op_monto_aprobado
# 272         820000       op_monto_aprobado
# 273         830000       op_monto_aprobado
# 274         840000       op_monto_aprobado
# 275         850000       op_monto_aprobado
# 276         860000       op_monto_aprobado
# 277         870000       op_monto_aprobado
# 278         480000       op_monto_aprobado
# 279         490000       op_monto_aprobado
# 280         500000       op_monto_aprobado
# 281         510000       op_monto_aprobado
# 282         520000       op_monto_aprobado
# 283         530000       op_monto_aprobado
# 284         540000       op_monto_aprobado
# 285         550000       op_monto_aprobado
# 286         560000       op_monto_aprobado
# 287         570000       op_monto_aprobado
# 288         580000       op_monto_aprobado
# 289         590000       op_monto_aprobado
# 290         600000       op_monto_aprobado
# 291         610000       op_monto_aprobado
# 292         620000       op_monto_aprobado
# 293         630000       op_monto_aprobado
# 294         640000       op_monto_aprobado
# 295         650000       op_monto_aprobado
# 296         660000       op_monto_aprobado
# 297         670000       op_monto_aprobado
# 298          15163     op_periodo_reajuste
# 299          16353     op_periodo_reajuste
# 300          25224     op_periodo_reajuste
# 301          25433     op_periodo_reajuste
# 302          25458     op_periodo_reajuste
# 303          25499     op_periodo_reajuste
# 304          25814     op_periodo_reajuste
# 305          25883     op_periodo_reajuste
# 306          25974     op_periodo_reajuste
# 307          25992     op_periodo_reajuste
# 308          26025     op_periodo_reajuste
# 309          26114     op_periodo_reajuste
# 310          10000     op_periodo_reajuste
# 311          20000     op_periodo_reajuste
# 312          30000     op_periodo_reajuste
# 313          40000     op_periodo_reajuste
# 314          50000     op_periodo_reajuste
# 315          60000     op_periodo_reajuste
# 316          70000     op_periodo_reajuste
# 317          80000     op_periodo_reajuste
# 318          90000     op_periodo_reajuste
# 319         100000     op_periodo_reajuste
# 320         110000     op_periodo_reajuste
# 321         120000     op_periodo_reajuste
# 322         130000     op_periodo_reajuste
# 323         140000     op_periodo_reajuste
# 324         150000     op_periodo_reajuste
# 325         160000     op_periodo_reajuste
# 326         170000     op_periodo_reajuste
# 327         180000     op_periodo_reajuste
# 328         190000     op_periodo_reajuste
# 329         200000     op_periodo_reajuste
# 330         210000     op_periodo_reajuste
# 331         220000     op_periodo_reajuste
# 332         230000     op_periodo_reajuste
# 333         240000     op_periodo_reajuste
# 334         250000     op_periodo_reajuste
# 335         260000     op_periodo_reajuste
# 336         270000     op_periodo_reajuste
# 337         280000     op_periodo_reajuste
# 338         290000     op_periodo_reajuste
# 339         300000     op_periodo_reajuste
# 340         310000     op_periodo_reajuste
# 341         320000     op_periodo_reajuste
# 342         330000     op_periodo_reajuste
# 343         340000     op_periodo_reajuste
# 344         350000     op_periodo_reajuste
# 345         360000     op_periodo_reajuste
# 346         370000     op_periodo_reajuste
# 347         380000     op_periodo_reajuste
# 348         390000     op_periodo_reajuste
# 349         400000     op_periodo_reajuste
# 350         410000     op_periodo_reajuste
# 351         420000     op_periodo_reajuste
# 352         430000     op_periodo_reajuste
# 353         440000     op_periodo_reajuste
# 354         450000     op_periodo_reajuste
# 355         460000     op_periodo_reajuste
# 356         470000     op_periodo_reajuste
# 357         680000     op_periodo_reajuste
# 358         690000     op_periodo_reajuste
# 359         700000     op_periodo_reajuste
# 360         710000     op_periodo_reajuste
# 361         720000     op_periodo_reajuste
# 362         730000     op_periodo_reajuste
# 363         740000     op_periodo_reajuste
# 364         750000     op_periodo_reajuste
# 365         760000     op_periodo_reajuste
# 366         770000     op_periodo_reajuste
# 367         780000     op_periodo_reajuste
# 368         790000     op_periodo_reajuste
# 369         800000     op_periodo_reajuste
# 370         810000     op_periodo_reajuste
# 371         820000     op_periodo_reajuste
# 372         830000     op_periodo_reajuste
# 373         840000     op_periodo_reajuste
# 374         850000     op_periodo_reajuste
# 375         860000     op_periodo_reajuste
# 376         870000     op_periodo_reajuste
# 377         480000     op_periodo_reajuste
# 378         490000     op_periodo_reajuste
# 379         500000     op_periodo_reajuste
# 380         510000     op_periodo_reajuste
# 381         520000     op_periodo_reajuste
# 382         530000     op_periodo_reajuste
# 383         540000     op_periodo_reajuste
# 384         550000     op_periodo_reajuste
# 385         560000     op_periodo_reajuste
# 386         570000     op_periodo_reajuste
# 387         580000     op_periodo_reajuste
# 388         590000     op_periodo_reajuste
# 389         600000     op_periodo_reajuste
# 390         610000     op_periodo_reajuste
# 391         620000     op_periodo_reajuste
# 392         630000     op_periodo_reajuste
# 393         640000     op_periodo_reajuste
# 394         650000     op_periodo_reajuste
# 395         660000     op_periodo_reajuste
# 396         670000     op_periodo_reajuste
# 397          15163            op_dias_anio
# 398          16353            op_dias_anio
# 399          25224            op_dias_anio
# 400          25433            op_dias_anio
# 401          25458            op_dias_anio
# 402          25499            op_dias_anio
# 403          25814            op_dias_anio
# 404          25883            op_dias_anio
# 405          25974            op_dias_anio
# 406          25992            op_dias_anio
# 407          26025            op_dias_anio
# 408          26114            op_dias_anio
# 409          10000            op_dias_anio
# 410          20000            op_dias_anio
# 411          30000            op_dias_anio
# 412          40000            op_dias_anio
# 413          50000            op_dias_anio
# 414          60000            op_dias_anio
# 415          70000            op_dias_anio
# 416          80000            op_dias_anio
# 417          90000            op_dias_anio
# 418         100000            op_dias_anio
# 419         110000            op_dias_anio
# 420         120000            op_dias_anio
# 421         130000            op_dias_anio
# 422         140000            op_dias_anio
# 423         150000            op_dias_anio
# 424         160000            op_dias_anio
# 425         170000            op_dias_anio
# 426         180000            op_dias_anio
# 427         190000            op_dias_anio
# 428         200000            op_dias_anio
# 429         210000            op_dias_anio
# 430         220000            op_dias_anio
# 431         230000            op_dias_anio
# 432         240000            op_dias_anio
# 433         250000            op_dias_anio
# 434         260000            op_dias_anio
# 435         270000            op_dias_anio
# 436         280000            op_dias_anio
# 437         290000            op_dias_anio
# 438         300000            op_dias_anio
# 439         310000            op_dias_anio
# 440         320000            op_dias_anio
# 441         330000            op_dias_anio
# 442         340000            op_dias_anio
# 443         350000            op_dias_anio
# 444         360000            op_dias_anio
# 445         370000            op_dias_anio
# 446         380000            op_dias_anio
# 447         390000            op_dias_anio
# 448         400000            op_dias_anio
# 449         410000            op_dias_anio
# 450         420000            op_dias_anio
# 451         430000            op_dias_anio
# 452         440000            op_dias_anio
# 453         450000            op_dias_anio
# 454         460000            op_dias_anio
# 455         470000            op_dias_anio
# 456         680000            op_dias_anio
# 457         690000            op_dias_anio
# 458         700000            op_dias_anio
# 459         710000            op_dias_anio
# 460         720000            op_dias_anio
# 461         730000            op_dias_anio
# 462         740000            op_dias_anio
# 463         750000            op_dias_anio
# 464         760000            op_dias_anio
# 465         770000            op_dias_anio
# 466         780000            op_dias_anio
# 467         790000            op_dias_anio
# 468         800000            op_dias_anio
# 469         810000            op_dias_anio
# 470         820000            op_dias_anio
# 471         830000            op_dias_anio
# 472         840000            op_dias_anio
# 473         850000            op_dias_anio
# 474         860000            op_dias_anio
# 475         870000            op_dias_anio
# 476         480000            op_dias_anio
# 477         490000            op_dias_anio
# 478         500000            op_dias_anio
# 479         510000            op_dias_anio
# 480         520000            op_dias_anio
# 481         530000            op_dias_anio
# 482         540000            op_dias_anio
# 483         550000            op_dias_anio
# 484         560000            op_dias_anio
# 485         570000            op_dias_anio
# 486         580000            op_dias_anio
# 487         590000            op_dias_anio
# 488         600000            op_dias_anio
# 489         610000            op_dias_anio
# 490         620000            op_dias_anio
# 491         630000            op_dias_anio
# 492         640000            op_dias_anio
# 493         650000            op_dias_anio
# 494         660000            op_dias_anio
# 495         670000            op_dias_anio
# 496          15163          op_periodo_cap
# 497          16353          op_periodo_cap
# 498          25224          op_periodo_cap
# 499          25433          op_periodo_cap
# 500          25458          op_periodo_cap
# 501          25499          op_periodo_cap
# 502          25814          op_periodo_cap
# 503          25883          op_periodo_cap
# 504          25974          op_periodo_cap
# 505          25992          op_periodo_cap
# 506          26025          op_periodo_cap
# 507          26114          op_periodo_cap
# 508          10000          op_periodo_cap
# 509          20000          op_periodo_cap
# 510          30000          op_periodo_cap
# 511          40000          op_periodo_cap
# 512          50000          op_periodo_cap
# 513          60000          op_periodo_cap
# 514          70000          op_periodo_cap
# 515          80000          op_periodo_cap
# 516          90000          op_periodo_cap
# 517         100000          op_periodo_cap
# 518         110000          op_periodo_cap
# 519         120000          op_periodo_cap
# 520         130000          op_periodo_cap
# 521         140000          op_periodo_cap
# 522         150000          op_periodo_cap
# 523         160000          op_periodo_cap
# 524         170000          op_periodo_cap
# 525         180000          op_periodo_cap
# 526         190000          op_periodo_cap
# 527         200000          op_periodo_cap
# 528         210000          op_periodo_cap
# 529         220000          op_periodo_cap
# 530         230000          op_periodo_cap
# 531         240000          op_periodo_cap
# 532         250000          op_periodo_cap
# 533         260000          op_periodo_cap
# 534         270000          op_periodo_cap
# 535         280000          op_periodo_cap
# 536         290000          op_periodo_cap
# 537         300000          op_periodo_cap
# 538         310000          op_periodo_cap
# 539         320000          op_periodo_cap
# 540         330000          op_periodo_cap
# 541         340000          op_periodo_cap
# 542         350000          op_periodo_cap
# 543         360000          op_periodo_cap
# 544         370000          op_periodo_cap
# 545         380000          op_periodo_cap
# 546         390000          op_periodo_cap
# 547         400000          op_periodo_cap
# 548         410000          op_periodo_cap
# 549         420000          op_periodo_cap
# 550         430000          op_periodo_cap
# 551         440000          op_periodo_cap
# 552         450000          op_periodo_cap
# 553         460000          op_periodo_cap
# 554         470000          op_periodo_cap
# 555         680000          op_periodo_cap
# 556         690000          op_periodo_cap
# 557         700000          op_periodo_cap
# 558         710000          op_periodo_cap
# 559         720000          op_periodo_cap
# 560         730000          op_periodo_cap
# 561         740000          op_periodo_cap
# 562         750000          op_periodo_cap
# 563         760000          op_periodo_cap
# 564         770000          op_periodo_cap
# 565         780000          op_periodo_cap
# 566         790000          op_periodo_cap
# 567         800000          op_periodo_cap
# 568         810000          op_periodo_cap
# 569         820000          op_periodo_cap
# 570         830000          op_periodo_cap
# 571         840000          op_periodo_cap
# 572         850000          op_periodo_cap
# 573         860000          op_periodo_cap
# 574         870000          op_periodo_cap
# 575         480000          op_periodo_cap
# 576         490000          op_periodo_cap
# 577         500000          op_periodo_cap
# 578         510000          op_periodo_cap
# 579         520000          op_periodo_cap
# 580         530000          op_periodo_cap
# 581         540000          op_periodo_cap
# 582         550000          op_periodo_cap
# 583         560000          op_periodo_cap
# 584         570000          op_periodo_cap
# 585         580000          op_periodo_cap
# 586         590000          op_periodo_cap
# 587         600000          op_periodo_cap
# 588         610000          op_periodo_cap
# 589         620000          op_periodo_cap
# 590         630000          op_periodo_cap
# 591         640000          op_periodo_cap
# 592         650000          op_periodo_cap
# 593         660000          op_periodo_cap
# 594         670000          op_periodo_cap
# 595          15163          op_periodo_int
# 596          16353          op_periodo_int
# 597          25224          op_periodo_int
# 598          25433          op_periodo_int
# 599          25458          op_periodo_int
# 600          25499          op_periodo_int
# 601          25814          op_periodo_int
# 602          25883          op_periodo_int
# 603          25974          op_periodo_int
# 604          25992          op_periodo_int
# 605          26025          op_periodo_int
# 606          26114          op_periodo_int
# 607          10000          op_periodo_int
# 608          20000          op_periodo_int
# 609          30000          op_periodo_int
# 610          40000          op_periodo_int
# 611          50000          op_periodo_int
# 612          60000          op_periodo_int
# 613          70000          op_periodo_int
# 614          80000          op_periodo_int
# 615          90000          op_periodo_int
# 616         100000          op_periodo_int
# 617         110000          op_periodo_int
# 618         120000          op_periodo_int
# 619         130000          op_periodo_int
# 620         140000          op_periodo_int
# 621         150000          op_periodo_int
# 622         160000          op_periodo_int
# 623         170000          op_periodo_int
# 624         180000          op_periodo_int
# 625         190000          op_periodo_int
# 626         200000          op_periodo_int
# 627         210000          op_periodo_int
# 628         220000          op_periodo_int
# 629         230000          op_periodo_int
# 630         240000          op_periodo_int
# 631         250000          op_periodo_int
# 632         260000          op_periodo_int
# 633         270000          op_periodo_int
# 634         280000          op_periodo_int
# 635         290000          op_periodo_int
# 636         300000          op_periodo_int
# 637         310000          op_periodo_int
# 638         320000          op_periodo_int
# 639         330000          op_periodo_int
# 640         340000          op_periodo_int
# 641         350000          op_periodo_int
# 642         360000          op_periodo_int
# 643         370000          op_periodo_int
# 644         380000          op_periodo_int
# 645         390000          op_periodo_int
# 646         400000          op_periodo_int
# 647         410000          op_periodo_int
# 648         420000          op_periodo_int
# 649         430000          op_periodo_int
# 650         440000          op_periodo_int
# 651         450000          op_periodo_int
# 652         460000          op_periodo_int
# 653         470000          op_periodo_int
# 654         680000          op_periodo_int
# 655         690000          op_periodo_int
# 656         700000          op_periodo_int
# 657         710000          op_periodo_int
# 658         720000          op_periodo_int
# 659         730000          op_periodo_int
# 660         740000          op_periodo_int
# 661         750000          op_periodo_int
# 662         760000          op_periodo_int
# 663         770000          op_periodo_int
# 664         780000          op_periodo_int
# 665         790000          op_periodo_int
# 666         800000          op_periodo_int
# 667         810000          op_periodo_int
# 668         820000          op_periodo_int
# 669         830000          op_periodo_int
# 670         840000          op_periodo_int
# 671         850000          op_periodo_int
# 672         860000          op_periodo_int
# 673         870000          op_periodo_int
# 674         480000          op_periodo_int
# 675         490000          op_periodo_int
# 676         500000          op_periodo_int
# 677         510000          op_periodo_int
# 678         520000          op_periodo_int
# 679         530000          op_periodo_int
# 680         540000          op_periodo_int
# 681         550000          op_periodo_int
# 682         560000          op_periodo_int
# 683         570000          op_periodo_int
# 684         580000          op_periodo_int
# 685         590000          op_periodo_int
# 686         600000          op_periodo_int
# 687         610000          op_periodo_int
# 688         620000          op_periodo_int
# 689         630000          op_periodo_int
# 690         640000          op_periodo_int
# 691         650000          op_periodo_int
# 692         660000          op_periodo_int
# 693         670000          op_periodo_int
# 694          15163          op_dist_gracia
# 695          16353          op_dist_gracia
# 696          25224          op_dist_gracia
# 697          25433          op_dist_gracia
# 698          25458          op_dist_gracia
# 699          25499          op_dist_gracia
# 700          25814          op_dist_gracia
# 701          25883          op_dist_gracia
# 702          25974          op_dist_gracia
# 703          25992          op_dist_gracia
# 704          26025          op_dist_gracia
# 705          26114          op_dist_gracia
# 706          10000          op_dist_gracia
# 707          20000          op_dist_gracia
# 708          30000          op_dist_gracia
# 709          40000          op_dist_gracia
# 710          50000          op_dist_gracia
# 711          60000          op_dist_gracia
# 712          70000          op_dist_gracia
# 713          80000          op_dist_gracia
# 714          90000          op_dist_gracia
# 715         100000          op_dist_gracia
# 716         110000          op_dist_gracia
# 717         120000          op_dist_gracia
# 718         130000          op_dist_gracia
# 719         140000          op_dist_gracia
# 720         150000          op_dist_gracia
# 721         160000          op_dist_gracia
# 722         170000          op_dist_gracia
# 723         180000          op_dist_gracia
# 724         190000          op_dist_gracia
# 725         200000          op_dist_gracia
# 726         210000          op_dist_gracia
# 727         220000          op_dist_gracia
# 728         230000          op_dist_gracia
# 729         240000          op_dist_gracia
# 730         250000          op_dist_gracia
# 731         260000          op_dist_gracia
# 732         270000          op_dist_gracia
# 733         280000          op_dist_gracia
# 734         290000          op_dist_gracia
# 735         300000          op_dist_gracia
# 736         310000          op_dist_gracia
# 737         320000          op_dist_gracia
# 738         330000          op_dist_gracia
# 739         340000          op_dist_gracia
# 740         350000          op_dist_gracia
# 741         360000          op_dist_gracia
# 742         370000          op_dist_gracia
# 743         380000          op_dist_gracia
# 744         390000          op_dist_gracia
# 745         400000          op_dist_gracia
# 746         410000          op_dist_gracia
# 747         420000          op_dist_gracia
# 748         430000          op_dist_gracia
# 749         440000          op_dist_gracia
# 750         450000          op_dist_gracia
# 751         460000          op_dist_gracia
# 752         470000          op_dist_gracia
# 753         680000          op_dist_gracia
# 754         690000          op_dist_gracia
# 755         700000          op_dist_gracia
# 756         710000          op_dist_gracia
# 757         720000          op_dist_gracia
# 758         730000          op_dist_gracia
# 759         740000          op_dist_gracia
# 760         750000          op_dist_gracia
# 761         760000          op_dist_gracia
# 762         770000          op_dist_gracia
# 763         780000          op_dist_gracia
# 764         790000          op_dist_gracia
# 765         800000          op_dist_gracia
# 766         810000          op_dist_gracia
# 767         820000          op_dist_gracia
# 768         830000          op_dist_gracia
# 769         840000          op_dist_gracia
# 770         850000          op_dist_gracia
# 771         860000          op_dist_gracia
# 772         870000          op_dist_gracia
# 773         480000          op_dist_gracia
# 774         490000          op_dist_gracia
# 775         500000          op_dist_gracia
# 776         510000          op_dist_gracia
# 777         520000          op_dist_gracia
# 778         530000          op_dist_gracia
# 779         540000          op_dist_gracia
# 780         550000          op_dist_gracia
# 781         560000          op_dist_gracia
# 782         570000          op_dist_gracia
# 783         580000          op_dist_gracia
# 784         590000          op_dist_gracia
# 785         600000          op_dist_gracia
# 786         610000          op_dist_gracia
# 787         620000          op_dist_gracia
# 788         630000          op_dist_gracia
# 789         640000          op_dist_gracia
# 790         650000          op_dist_gracia
# 791         660000          op_dist_gracia
# 792         670000          op_dist_gracia
# 793          15163                op_clase
# 794          16353                op_clase
# 795          25224                op_clase
# 796          25433                op_clase
# 797          25458                op_clase
# 798          25499                op_clase
# 799          25814                op_clase
# 800          25883                op_clase
# 801          25974                op_clase
# 802          25992                op_clase
# 803          26025                op_clase
# 804          26114                op_clase
# 805          10000                op_clase
# 806          20000                op_clase
# 807          30000                op_clase
# 808          40000                op_clase
# 809          50000                op_clase
# 810          60000                op_clase
# 811          70000                op_clase
# 812          80000                op_clase
# 813          90000                op_clase
# 814         100000                op_clase
# 815         110000                op_clase
# 816         120000                op_clase
# 817         130000                op_clase
# 818         140000                op_clase
# 819         150000                op_clase
# 820         160000                op_clase
# 821         170000                op_clase
# 822         180000                op_clase
# 823         190000                op_clase
# 824         200000                op_clase
# 825         210000                op_clase
# 826         220000                op_clase
# 827         230000                op_clase
# 828         240000                op_clase
# 829         250000                op_clase
# 830         260000                op_clase
# 831         270000                op_clase
# 832         280000                op_clase
# 833         290000                op_clase
# 834         300000                op_clase
# 835         310000                op_clase
# 836         320000                op_clase
# 837         330000                op_clase
# 838         340000                op_clase
# 839         350000                op_clase
# 840         360000                op_clase
# 841         370000                op_clase
# 842         380000                op_clase
# 843         390000                op_clase
# 844         400000                op_clase
# 845         410000                op_clase
# 846         420000                op_clase
# 847         430000                op_clase
# 848         440000                op_clase
# 849         450000                op_clase
# 850         460000                op_clase
# 851         470000                op_clase
# 852         680000                op_clase
# 853         690000                op_clase
# 854         700000                op_clase
# 855         710000                op_clase
# 856         720000                op_clase
# 857         730000                op_clase
# 858         740000                op_clase
# 859         750000                op_clase
# 860         760000                op_clase
# 861         770000                op_clase
# 862         780000                op_clase
# 863         790000                op_clase
# 864         800000                op_clase
# 865         810000                op_clase
# 866         820000                op_clase
# 867         830000                op_clase
# 868         840000                op_clase
# 869         850000                op_clase
# 870         860000                op_clase
# 871         870000                op_clase
# 872         480000                op_clase
# 873         490000                op_clase
# 874         500000                op_clase
# 875         510000                op_clase
# 876         520000                op_clase
# 877         530000                op_clase
# 878         540000                op_clase
# 879         550000                op_clase
# 880         560000                op_clase
# 881         570000                op_clase
# 882         580000                op_clase
# 883         590000                op_clase
# 884         600000                op_clase
# 885         610000                op_clase
# 886         620000                op_clase
# 887         630000                op_clase
# 888         640000                op_clase
# 889         650000                op_clase
# 890         660000                op_clase
# 891         670000                op_clase
# 892          15163        op_origen_fondos
# 893          16353        op_origen_fondos
# 894          25224        op_origen_fondos
# 895          25433        op_origen_fondos
# 896          25458        op_origen_fondos
# 897          25499        op_origen_fondos
# 898          25814        op_origen_fondos
# 899          25883        op_origen_fondos
# 900          25974        op_origen_fondos
# 901          25992        op_origen_fondos
# 902          26025        op_origen_fondos
# 903          26114        op_origen_fondos
# 904          10000        op_origen_fondos
# 905          20000        op_origen_fondos
# 906          30000        op_origen_fondos
# 907          40000        op_origen_fondos
# 908          50000        op_origen_fondos
# 909          60000        op_origen_fondos
# 910          70000        op_origen_fondos
# 911          80000        op_origen_fondos
# 912          90000        op_origen_fondos
# 913         100000        op_origen_fondos
# 914         110000        op_origen_fondos
# 915         120000        op_origen_fondos
# 916         130000        op_origen_fondos
# 917         140000        op_origen_fondos
# 918         150000        op_origen_fondos
# 919         160000        op_origen_fondos
# 920         170000        op_origen_fondos
# 921         180000        op_origen_fondos
# 922         190000        op_origen_fondos
# 923         200000        op_origen_fondos
# 924         210000        op_origen_fondos
# 925         220000        op_origen_fondos
# 926         230000        op_origen_fondos
# 927         240000        op_origen_fondos
# 928         250000        op_origen_fondos
# 929         260000        op_origen_fondos
# 930         270000        op_origen_fondos
# 931         280000        op_origen_fondos
# 932         290000        op_origen_fondos
# 933         300000        op_origen_fondos
# 934         310000        op_origen_fondos
# 935         320000        op_origen_fondos
# 936         330000        op_origen_fondos
# 937         340000        op_origen_fondos
# 938         350000        op_origen_fondos
# 939         360000        op_origen_fondos
# 940         370000        op_origen_fondos
# 941         380000        op_origen_fondos
# 942         390000        op_origen_fondos
# 943         400000        op_origen_fondos
# 944         410000        op_origen_fondos
# 945         420000        op_origen_fondos
# 946         430000        op_origen_fondos
# 947         440000        op_origen_fondos
# 948         450000        op_origen_fondos
# 949         460000        op_origen_fondos
# 950         470000        op_origen_fondos
# 951         680000        op_origen_fondos
# 952         690000        op_origen_fondos
# 953         700000        op_origen_fondos
# 954         710000        op_origen_fondos
# 955         720000        op_origen_fondos
# 956         730000        op_origen_fondos
# 957         740000        op_origen_fondos
# 958         750000        op_origen_fondos
# 959         760000        op_origen_fondos
# 960         770000        op_origen_fondos
# 961         780000        op_origen_fondos
# 962         790000        op_origen_fondos
# 963         800000        op_origen_fondos
# 964         810000        op_origen_fondos
# 965         820000        op_origen_fondos
# 966         830000        op_origen_fondos
# 967         840000        op_origen_fondos
# 968         850000        op_origen_fondos
# 969         860000        op_origen_fondos
# 970         870000        op_origen_fondos
# 971         480000        op_origen_fondos
# 972         490000        op_origen_fondos
# 973         500000        op_origen_fondos
# 974         510000        op_origen_fondos
# 975         520000        op_origen_fondos
# 976         530000        op_origen_fondos
# 977         540000        op_origen_fondos
# 978         550000        op_origen_fondos
# 979         560000        op_origen_fondos
# 980         570000        op_origen_fondos
# 981         580000        op_origen_fondos
# 982         590000        op_origen_fondos
# 983         600000        op_origen_fondos
# 984         610000        op_origen_fondos
# 985         620000        op_origen_fondos
# 986         630000        op_origen_fondos
# 987         640000        op_origen_fondos
# 988         650000        op_origen_fondos
# 989         660000        op_origen_fondos
# 990         670000        op_origen_fondos
# 991          16353       op_fecha_pri_cuot
# 992          25224       op_fecha_pri_cuot
# 993          25458       op_fecha_pri_cuot
# 994          25883       op_fecha_pri_cuot
# 995          25974       op_fecha_pri_cuot
# 996          25992       op_fecha_pri_cuot
# 997          10000       op_fecha_pri_cuot
# 998          20000       op_fecha_pri_cuot
# 999          40000       op_fecha_pri_cuot
# 1000         60000       op_fecha_pri_cuot
# 1001        100000       op_fecha_pri_cuot
# 1002        110000       op_fecha_pri_cuot
# 1003        140000       op_fecha_pri_cuot
# 1004        150000       op_fecha_pri_cuot
# 1005        170000       op_fecha_pri_cuot
# 1006        190000       op_fecha_pri_cuot
# 1007        230000       op_fecha_pri_cuot
# 1008        240000       op_fecha_pri_cuot
# 1009        270000       op_fecha_pri_cuot
# 1010        280000       op_fecha_pri_cuot
# 1011        300000       op_fecha_pri_cuot
# 1012        320000       op_fecha_pri_cuot
# 1013        360000       op_fecha_pri_cuot
# 1014        370000       op_fecha_pri_cuot
# 1015        400000       op_fecha_pri_cuot
# 1016        410000       op_fecha_pri_cuot
# 1017        430000       op_fecha_pri_cuot
# 1018        450000       op_fecha_pri_cuot
# 1019        690000       op_fecha_pri_cuot
# 1020        710000       op_fecha_pri_cuot
# 1021        750000       op_fecha_pri_cuot
# 1022        760000       op_fecha_pri_cuot
# 1023        790000       op_fecha_pri_cuot
# 1024        800000       op_fecha_pri_cuot
# 1025        820000       op_fecha_pri_cuot
# 1026        840000       op_fecha_pri_cuot
# 1027        490000       op_fecha_pri_cuot
# 1028        500000       op_fecha_pri_cuot
# 1029        530000       op_fecha_pri_cuot
# 1030        540000       op_fecha_pri_cuot
# 1031        560000       op_fecha_pri_cuot
# 1032        580000       op_fecha_pri_cuot
# 1033        620000       op_fecha_pri_cuot
# 1034        630000       op_fecha_pri_cuot
# 1035        660000       op_fecha_pri_cuot
# 1036        670000       op_fecha_pri_cuot
# 1037         15163  op_fecha_ult_causacion
# 1038         16353  op_fecha_ult_causacion
# 1039         25224  op_fecha_ult_causacion
# 1040         25433  op_fecha_ult_causacion
# 1041         25458  op_fecha_ult_causacion
# 1042         25499  op_fecha_ult_causacion
# 1043         25814  op_fecha_ult_causacion
# 1044         25883  op_fecha_ult_causacion
# 1045         25974  op_fecha_ult_causacion
# 1046         25992  op_fecha_ult_causacion
# 1047         26025  op_fecha_ult_causacion
# 1048         26114  op_fecha_ult_causacion
# 1049         10000  op_fecha_ult_causacion
# 1050         20000  op_fecha_ult_causacion
# 1051         30000  op_fecha_ult_causacion
# 1052         40000  op_fecha_ult_causacion
# 1053         50000  op_fecha_ult_causacion
# 1054         60000  op_fecha_ult_causacion
# 1055         70000  op_fecha_ult_causacion
# 1056         80000  op_fecha_ult_causacion
# 1057         90000  op_fecha_ult_causacion
# 1058        100000  op_fecha_ult_causacion
# 1059        110000  op_fecha_ult_causacion
# 1060        120000  op_fecha_ult_causacion
# 1061        130000  op_fecha_ult_causacion
# 1062        140000  op_fecha_ult_causacion
# 1063        150000  op_fecha_ult_causacion
# 1064        160000  op_fecha_ult_causacion
# 1065        170000  op_fecha_ult_causacion
# 1066        180000  op_fecha_ult_causacion
# 1067        190000  op_fecha_ult_causacion
# 1068        200000  op_fecha_ult_causacion
# 1069        210000  op_fecha_ult_causacion
# 1070        220000  op_fecha_ult_causacion
# 1071        230000  op_fecha_ult_causacion
# 1072        240000  op_fecha_ult_causacion
# 1073        250000  op_fecha_ult_causacion
# 1074        260000  op_fecha_ult_causacion
# 1075        270000  op_fecha_ult_causacion
# 1076        280000  op_fecha_ult_causacion
# 1077        290000  op_fecha_ult_causacion
# 1078        300000  op_fecha_ult_causacion
# 1079        310000  op_fecha_ult_causacion
# 1080        320000  op_fecha_ult_causacion
# 1081        330000  op_fecha_ult_causacion
# 1082        340000  op_fecha_ult_causacion
# 1083        350000  op_fecha_ult_causacion
# 1084        360000  op_fecha_ult_causacion
# 1085        370000  op_fecha_ult_causacion
# 1086        380000  op_fecha_ult_causacion
# 1087        390000  op_fecha_ult_causacion
# 1088        400000  op_fecha_ult_causacion
# 1089        410000  op_fecha_ult_causacion
# 1090        420000  op_fecha_ult_causacion
# 1091        430000  op_fecha_ult_causacion
# 1092        440000  op_fecha_ult_causacion
# 1093        450000  op_fecha_ult_causacion
# 1094        460000  op_fecha_ult_causacion
# 1095        470000  op_fecha_ult_causacion
# 1096        680000  op_fecha_ult_causacion
# 1097        690000  op_fecha_ult_causacion
# 1098        700000  op_fecha_ult_causacion
# 1099        710000  op_fecha_ult_causacion
# 1100        720000  op_fecha_ult_causacion
# 1101        730000  op_fecha_ult_causacion
# 1102        740000  op_fecha_ult_causacion
# 1103        750000  op_fecha_ult_causacion
# 1104        760000  op_fecha_ult_causacion
# 1105        770000  op_fecha_ult_causacion
# 1106        780000  op_fecha_ult_causacion
# 1107        790000  op_fecha_ult_causacion
# 1108        800000  op_fecha_ult_causacion
# 1109        810000  op_fecha_ult_causacion
# 1110        820000  op_fecha_ult_causacion
# 1111        830000  op_fecha_ult_causacion
# 1112        840000  op_fecha_ult_causacion
# 1113        850000  op_fecha_ult_causacion
# 1114        860000  op_fecha_ult_causacion
# ...
# 1853        150000   op_fecha_ult_pago_int
# 1854        160000   op_fecha_ult_pago_int
# 1855        170000   op_fecha_ult_pago_int
# 1856        180000   op_fecha_ult_pago_int
# 1857        190000   op_fecha_ult_pago_int
# 1858        200000   op_fecha_ult_pago_int
# 1859        210000   op_fecha_ult_pago_int
# 1860        220000   op_fecha_ult_pago_int
# 1861        230000   op_fecha_ult_pago_int
# 1862        250000   op_fecha_ult_pago_int
# 1863        260000   op_fecha_ult_pago_int
# 1864        270000   op_fecha_ult_pago_int
# 1865        280000   op_fecha_ult_pago_int
# 1866        290000   op_fecha_ult_pago_int
# 1867        300000   op_fecha_ult_pago_int
# 1868        310000   op_fecha_ult_pago_int
# 1869        320000   op_fecha_ult_pago_int
# 1870        330000   op_fecha_ult_pago_int
# 1871        340000   op_fecha_ult_pago_int
# 1872        350000   op_fecha_ult_pago_int
# 1873        360000   op_fecha_ult_pago_int
# 1874        380000   op_fecha_ult_pago_int
# 1875        390000   op_fecha_ult_pago_int
# 1876        400000   op_fecha_ult_pago_int
# 1877        410000   op_fecha_ult_pago_int
# 1878        420000   op_fecha_ult_pago_int
# 1879        430000   op_fecha_ult_pago_int
# 1880        440000   op_fecha_ult_pago_int
# 1881        450000   op_fecha_ult_pago_int
# 1882        460000   op_fecha_ult_pago_int
# 1883        470000   op_fecha_ult_pago_int
# 1884        680000   op_fecha_ult_pago_int
# 1885        690000   op_fecha_ult_pago_int
# 1886        700000   op_fecha_ult_pago_int
# 1887        710000   op_fecha_ult_pago_int
# 1888        720000   op_fecha_ult_pago_int
# 1889        730000   op_fecha_ult_pago_int
# 1890        740000   op_fecha_ult_pago_int
# 1891        750000   op_fecha_ult_pago_int
# 1892        770000   op_fecha_ult_pago_int
# 1893        780000   op_fecha_ult_pago_int
# 1894        790000   op_fecha_ult_pago_int
# 1895        800000   op_fecha_ult_pago_int
# 1896        810000   op_fecha_ult_pago_int
# 1897        820000   op_fecha_ult_pago_int
# 1898        830000   op_fecha_ult_pago_int
# 1899        840000   op_fecha_ult_pago_int
# 1900        850000   op_fecha_ult_pago_int
# 1901        860000   op_fecha_ult_pago_int
# 1902        870000   op_fecha_ult_pago_int
# 1903        480000   op_fecha_ult_pago_int
# 1904        490000   op_fecha_ult_pago_int
# 1905        510000   op_fecha_ult_pago_int
# 1906        520000   op_fecha_ult_pago_int
# 1907        530000   op_fecha_ult_pago_int
# 1908        540000   op_fecha_ult_pago_int
# 1909        550000   op_fecha_ult_pago_int
# 1910        560000   op_fecha_ult_pago_int
# 1911        570000   op_fecha_ult_pago_int
# 1912        580000   op_fecha_ult_pago_int
# 1913        590000   op_fecha_ult_pago_int
# 1914        600000   op_fecha_ult_pago_int
# 1915        610000   op_fecha_ult_pago_int
# 1916        620000   op_fecha_ult_pago_int
# 1917        640000   op_fecha_ult_pago_int
# 1918        650000   op_fecha_ult_pago_int
# 1919        660000   op_fecha_ult_pago_int
# 1920        670000   op_fecha_ult_pago_int
# 1921         15163       op_monto_ult_pago
# 1922         16353       op_monto_ult_pago
# 1923         25224       op_monto_ult_pago
# 1924         25433       op_monto_ult_pago
# 1925         25458       op_monto_ult_pago
# 1926         25499       op_monto_ult_pago
# 1927         25814       op_monto_ult_pago
# 1928         25883       op_monto_ult_pago
# 1929         25974       op_monto_ult_pago
# 1930         25992       op_monto_ult_pago
# 1931         26025       op_monto_ult_pago
# 1932         26114       op_monto_ult_pago
# 1933         10000       op_monto_ult_pago
# 1934         20000       op_monto_ult_pago
# 1935         30000       op_monto_ult_pago
# 1936         40000       op_monto_ult_pago
# 1937         50000       op_monto_ult_pago
# 1938         60000       op_monto_ult_pago
# 1939         70000       op_monto_ult_pago
# 1940         80000       op_monto_ult_pago
# 1941         90000       op_monto_ult_pago
# 1942        100000       op_monto_ult_pago
# 1943        110000       op_monto_ult_pago
# 1944        120000       op_monto_ult_pago
# 1945        130000       op_monto_ult_pago
# 1946        140000       op_monto_ult_pago
# 1947        150000       op_monto_ult_pago
# 1948        160000       op_monto_ult_pago
# 1949        170000       op_monto_ult_pago
# 1950        180000       op_monto_ult_pago
# 1951        190000       op_monto_ult_pago
# 1952        200000       op_monto_ult_pago
# 1953        210000       op_monto_ult_pago
# 1954        220000       op_monto_ult_pago
# 1955        230000       op_monto_ult_pago
# 1956        240000       op_monto_ult_pago
# 1957        250000       op_monto_ult_pago
# 1958        260000       op_monto_ult_pago
# 1959        270000       op_monto_ult_pago
# 1960        280000       op_monto_ult_pago
# 1961        290000       op_monto_ult_pago
# 1962        300000       op_monto_ult_pago
# 1963        310000       op_monto_ult_pago
# 1964        320000       op_monto_ult_pago
# 1965        330000       op_monto_ult_pago
# 1966        340000       op_monto_ult_pago
# 1967        350000       op_monto_ult_pago
# 1968        360000       op_monto_ult_pago
# 1969        370000       op_monto_ult_pago
# 1970        380000       op_monto_ult_pago
# 1971        390000       op_monto_ult_pago
# 1972        400000       op_monto_ult_pago
# 1973        410000       op_monto_ult_pago
# 1974        420000       op_monto_ult_pago
# 1975        430000       op_monto_ult_pago
# 1976        440000       op_monto_ult_pago
# 1977        450000       op_monto_ult_pago
# 1978        460000       op_monto_ult_pago
# 1979        470000       op_monto_ult_pago
# 1980        680000       op_monto_ult_pago
# 1981        690000       op_monto_ult_pago
# 1982        700000       op_monto_ult_pago
# 1983        710000       op_monto_ult_pago
# 1984        720000       op_monto_ult_pago
# 1985        730000       op_monto_ult_pago
# 1986        740000       op_monto_ult_pago
# 1987        750000       op_monto_ult_pago
# 1988        760000       op_monto_ult_pago
# 1989        770000       op_monto_ult_pago
# 1990        780000       op_monto_ult_pago
# 1991        790000       op_monto_ult_pago
# 1992        800000       op_monto_ult_pago
# 1993        810000       op_monto_ult_pago
# 1994        820000       op_monto_ult_pago
# 1995        830000       op_monto_ult_pago
# 1996        840000       op_monto_ult_pago
# 1997        850000       op_monto_ult_pago
# 1998        860000       op_monto_ult_pago
# 1999        870000       op_monto_ult_pago
# 2000        480000       op_monto_ult_pago
# 2001        490000       op_monto_ult_pago
# 2002        500000       op_monto_ult_pago
# 2003        510000       op_monto_ult_pago
# 2004        520000       op_monto_ult_pago
# 2005        530000       op_monto_ult_pago
# 2006        540000       op_monto_ult_pago
# 2007        550000       op_monto_ult_pago
# 2008        560000       op_monto_ult_pago
# 2009        570000       op_monto_ult_pago
# 2010        580000       op_monto_ult_pago
# 2011        590000       op_monto_ult_pago
# 2012        600000       op_monto_ult_pago
# 2013        610000       op_monto_ult_pago
# 2014        620000       op_monto_ult_pago
# 2015        630000       op_monto_ult_pago
# 2016        640000       op_monto_ult_pago
# 2017        650000       op_monto_ult_pago
# 2018        660000       op_monto_ult_pago
# 2019        670000       op_monto_ult_pago
# 2020         15163   op_monto_ult_pago_cap
# 2021         16353   op_monto_ult_pago_cap
# 2022         25224   op_monto_ult_pago_cap
# 2023         25433   op_monto_ult_pago_cap
# 2024         25458   op_monto_ult_pago_cap
# 2025         25499   op_monto_ult_pago_cap
# 2026         25814   op_monto_ult_pago_cap
# 2027         25883   op_monto_ult_pago_cap
# 2028         25974   op_monto_ult_pago_cap
# 2029         25992   op_monto_ult_pago_cap
# 2030         26025   op_monto_ult_pago_cap
# 2031         26114   op_monto_ult_pago_cap
# 2032         10000   op_monto_ult_pago_cap
# 2033         20000   op_monto_ult_pago_cap
# 2034         30000   op_monto_ult_pago_cap
# 2035         40000   op_monto_ult_pago_cap
# 2036         50000   op_monto_ult_pago_cap
# 2037         60000   op_monto_ult_pago_cap
# 2038         70000   op_monto_ult_pago_cap
# 2039         80000   op_monto_ult_pago_cap
# 2040         90000   op_monto_ult_pago_cap
# 2041        100000   op_monto_ult_pago_cap
# 2042        110000   op_monto_ult_pago_cap
# 2043        120000   op_monto_ult_pago_cap
# 2044        130000   op_monto_ult_pago_cap
# 2045        140000   op_monto_ult_pago_cap
# 2046        150000   op_monto_ult_pago_cap
# 2047        160000   op_monto_ult_pago_cap
# 2048        170000   op_monto_ult_pago_cap
# 2049        180000   op_monto_ult_pago_cap
# 2050        190000   op_monto_ult_pago_cap
# 2051        200000   op_monto_ult_pago_cap
# 2052        210000   op_monto_ult_pago_cap
# 2053        220000   op_monto_ult_pago_cap
# 2054        230000   op_monto_ult_pago_cap
# 2055        240000   op_monto_ult_pago_cap
# 2056        250000   op_monto_ult_pago_cap
# 2057        260000   op_monto_ult_pago_cap
# 2058        270000   op_monto_ult_pago_cap
# 2059        280000   op_monto_ult_pago_cap
# 2060        290000   op_monto_ult_pago_cap
# 2061        300000   op_monto_ult_pago_cap
# 2062        310000   op_monto_ult_pago_cap
# 2063        320000   op_monto_ult_pago_cap
# 2064        330000   op_monto_ult_pago_cap
# 2065        340000   op_monto_ult_pago_cap
# 2066        350000   op_monto_ult_pago_cap
# 2067        360000   op_monto_ult_pago_cap
# 2068        370000   op_monto_ult_pago_cap
# 2069        380000   op_monto_ult_pago_cap
# 2070        390000   op_monto_ult_pago_cap
# 2071        400000   op_monto_ult_pago_cap
# 2072        410000   op_monto_ult_pago_cap
# 2073        420000   op_monto_ult_pago_cap
# 2074        430000   op_monto_ult_pago_cap
# 2075        440000   op_monto_ult_pago_cap
# 2076        450000   op_monto_ult_pago_cap
# 2077        460000   op_monto_ult_pago_cap
# 2078        470000   op_monto_ult_pago_cap
# 2079        680000   op_monto_ult_pago_cap
# 2080        690000   op_monto_ult_pago_cap
# 2081        700000   op_monto_ult_pago_cap
# 2082        710000   op_monto_ult_pago_cap
# 2083        720000   op_monto_ult_pago_cap
# 2084        730000   op_monto_ult_pago_cap
# 2085        740000   op_monto_ult_pago_cap
# 2086        750000   op_monto_ult_pago_cap
# 2087        760000   op_monto_ult_pago_cap
# 2088        770000   op_monto_ult_pago_cap
# 2089        780000   op_monto_ult_pago_cap
# 2090        790000   op_monto_ult_pago_cap
# 2091        800000   op_monto_ult_pago_cap
# 2092        810000   op_monto_ult_pago_cap
# 2093        820000   op_monto_ult_pago_cap
# 2094        830000   op_monto_ult_pago_cap
# 2095        840000   op_monto_ult_pago_cap
# 2096        850000   op_monto_ult_pago_cap
# 2097        860000   op_monto_ult_pago_cap
# 2098        870000   op_monto_ult_pago_cap
# 2099        480000   op_monto_ult_pago_cap
# 2100        490000   op_monto_ult_pago_cap
# 2101        500000   op_monto_ult_pago_cap
# 2102        510000   op_monto_ult_pago_cap
# 2103        520000   op_monto_ult_pago_cap
# 2104        530000   op_monto_ult_pago_cap
# 2105        540000   op_monto_ult_pago_cap
# 2106        550000   op_monto_ult_pago_cap
# 2107        560000   op_monto_ult_pago_cap
# 2108        570000   op_monto_ult_pago_cap
# 2109        580000   op_monto_ult_pago_cap
# 2110        590000   op_monto_ult_pago_cap
# 2111        600000   op_monto_ult_pago_cap
# 2112        610000   op_monto_ult_pago_cap
# 2113        620000   op_monto_ult_pago_cap
# 2114        630000   op_monto_ult_pago_cap
# 2115        640000   op_monto_ult_pago_cap
# 2116        650000   op_monto_ult_pago_cap
# 2117        660000   op_monto_ult_pago_cap
# 2118        670000   op_monto_ult_pago_cap
# 2119         15163   op_monto_ult_pago_int
# 2120         16353   op_monto_ult_pago_int
# 2121         25224   op_monto_ult_pago_int
# 2122         25433   op_monto_ult_pago_int
# 2123         25458   op_monto_ult_pago_int
# 2124         25499   op_monto_ult_pago_int
# 2125         25814   op_monto_ult_pago_int
# 2126         25883   op_monto_ult_pago_int
# 2127         25974   op_monto_ult_pago_int
# 2128         26025   op_monto_ult_pago_int
# 2129         26114   op_monto_ult_pago_int
# 2130         10000   op_monto_ult_pago_int
# 2131         20000   op_monto_ult_pago_int
# 2132         30000   op_monto_ult_pago_int
# 2133         40000   op_monto_ult_pago_int
# 2134         50000   op_monto_ult_pago_int
# 2135         60000   op_monto_ult_pago_int
# 2136         70000   op_monto_ult_pago_int
# 2137         80000   op_monto_ult_pago_int
# 2138         90000   op_monto_ult_pago_int
# 2139        100000   op_monto_ult_pago_int
# 2140        120000   op_monto_ult_pago_int
# 2141        130000   op_monto_ult_pago_int
# 2142        140000   op_monto_ult_pago_int
# 2143        150000   op_monto_ult_pago_int
# 2144        160000   op_monto_ult_pago_int
# 2145        170000   op_monto_ult_pago_int
# 2146        180000   op_monto_ult_pago_int
# 2147        190000   op_monto_ult_pago_int
# 2148        200000   op_monto_ult_pago_int
# 2149        210000   op_monto_ult_pago_int
# 2150        220000   op_monto_ult_pago_int
# 2151        230000   op_monto_ult_pago_int
# 2152        250000   op_monto_ult_pago_int
# 2153        260000   op_monto_ult_pago_int
# 2154        270000   op_monto_ult_pago_int
# 2155        280000   op_monto_ult_pago_int
# 2156        290000   op_monto_ult_pago_int
# 2157        300000   op_monto_ult_pago_int
# 2158        310000   op_monto_ult_pago_int
# 2159        320000   op_monto_ult_pago_int
# 2160        330000   op_monto_ult_pago_int
# 2161        340000   op_monto_ult_pago_int
# 2162        350000   op_monto_ult_pago_int
# 2163        360000   op_monto_ult_pago_int
# 2164        380000   op_monto_ult_pago_int
# 2165        390000   op_monto_ult_pago_int
# 2166        400000   op_monto_ult_pago_int
# 2167        410000   op_monto_ult_pago_int
# 2168        420000   op_monto_ult_pago_int
# 2169        430000   op_monto_ult_pago_int
# 2170        440000   op_monto_ult_pago_int
# 2171        450000   op_monto_ult_pago_int
# 2172        460000   op_monto_ult_pago_int
# 2173        470000   op_monto_ult_pago_int
# 2174        680000   op_monto_ult_pago_int
# 2175        690000   op_monto_ult_pago_int
# 2176        700000   op_monto_ult_pago_int
# 2177        710000   op_monto_ult_pago_int
# 2178        720000   op_monto_ult_pago_int
# 2179        730000   op_monto_ult_pago_int
# 2180        740000   op_monto_ult_pago_int
# 2181        750000   op_monto_ult_pago_int
# 2182        770000   op_monto_ult_pago_int
# 2183        780000   op_monto_ult_pago_int
# 2184        790000   op_monto_ult_pago_int
# 2185        800000   op_monto_ult_pago_int
# 2186        810000   op_monto_ult_pago_int
# 2187        820000   op_monto_ult_pago_int
# 2188        830000   op_monto_ult_pago_int
# 2189        840000   op_monto_ult_pago_int
# 2190        850000   op_monto_ult_pago_int
# 2191        860000   op_monto_ult_pago_int
# 2192        870000   op_monto_ult_pago_int
# 2193        480000   op_monto_ult_pago_int
# 2194        490000   op_monto_ult_pago_int
# 2195        510000   op_monto_ult_pago_int
# 2196        520000   op_monto_ult_pago_int
# 2197        530000   op_monto_ult_pago_int
# 2198        540000   op_monto_ult_pago_int
# 2199        550000   op_monto_ult_pago_int
# 2200        560000   op_monto_ult_pago_int
# 2201        570000   op_monto_ult_pago_int
# 2202        580000   op_monto_ult_pago_int
# 2203        590000   op_monto_ult_pago_int
# 2204        600000   op_monto_ult_pago_int
# 2205        610000   op_monto_ult_pago_int
# 2206        620000   op_monto_ult_pago_int
# 2207        640000   op_monto_ult_pago_int
# 2208        650000   op_monto_ult_pago_int
# 2209        660000   op_monto_ult_pago_int
# 2210        670000   op_monto_ult_pago_int
# 2211         70000        op_vta_comprador
# 2212        200000        op_vta_comprador
# 2213        330000        op_vta_comprador
# 2214        460000        op_vta_comprador
# 2215        720000        op_vta_comprador
# 2216        850000        op_vta_comprador
# 2217        590000        op_vta_comprador
# 2218         70000            op_vta_fecha
# 2219        200000            op_vta_fecha
# 2220        330000            op_vta_fecha
# 2221        460000            op_vta_fecha
# 2222        720000            op_vta_fecha
# 2223        850000            op_vta_fecha
# 2224        590000            op_vta_fecha
